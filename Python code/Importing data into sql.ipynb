# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
df1=pd.read_csv("Dim_Crime.csv")

# %%
df2=pd.read_csv("Dim_Location.csv")

# %%
df3=pd.read_csv("Dim_Victim.csv")

# %%
df4=pd.read_csv("Dim_Weapon.csv")

# %%
df5=pd.read_csv("Fact_Crime.csv")

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime")
df1.to_sql("Dim_Crime", con=engine, if_exists="replace", index=False)
print("Done!")
# Out:
# Done!
# C:\Users\satya\AppData\Local\Temp\ipykernel_1080\4165978792.py:2: UserWarning: The provided table name 'Dim_Crime' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df1.to_sql("Dim_Crime", con=engine, if_exists="replace", index=False)

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime")
df2.to_sql("Dim_Location", con=engine, if_exists="replace", index=False)
print("Done!")
# Out:
# Done!
# C:\Users\satya\AppData\Local\Temp\ipykernel_1080\50812171.py:2: UserWarning: The provided table name 'Dim_Location' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df2.to_sql("Dim_Location", con=engine, if_exists="replace", index=False)

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime")
df3.to_sql("Dim_Victim", con=engine, if_exists="replace", index=False)
print("Done!")
# Out:
# Done!
# C:\Users\satya\AppData\Local\Temp\ipykernel_1080\377220835.py:2: UserWarning: The provided table name 'Dim_Victim' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df3.to_sql("Dim_Victim", con=engine, if_exists="replace", index=False)

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime")
df4.to_sql("Dim_Weapon", con=engine, if_exists="replace", index=False)
print("Done!")
# Out:
# Done!
# C:\Users\satya\AppData\Local\Temp\ipykernel_1080\1716922377.py:2: UserWarning: The provided table name 'Dim_Weapon' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df4.to_sql("Dim_Weapon", con=engine, if_exists="replace", index=False)

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime")
df5.to_sql("Fact_Crime", con=engine, if_exists="replace", index=False)
print("Done!")
# Out:
# Done!
# C:\Users\satya\AppData\Local\Temp\ipykernel_1080\1058986079.py:2: UserWarning: The provided table name 'Fact_Crime' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df5.to_sql("Fact_Crime", con=engine, if_exists="replace", index=False)
