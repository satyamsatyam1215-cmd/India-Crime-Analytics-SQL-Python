# %%
import pandas as pd 
from sqlalchemy import create_engine

# %%
df=pd.read_csv("C:\\Users\\satya\\OneDrive\\Desktop\\Git hub repos\\India-Crime-Analytics-SQL-Python\\Data\\crime_dataset_india.csv")

# %%
engine = create_engine("mysql+mysqlconnector://root:Satyam%40456@localhost:3306/crime_db")

# %%
df.to_sql("Crime_data",con=engine,if_exists="replace",index=False)
